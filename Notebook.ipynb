# %%
from scrapers import *
from IPython.display import display, Markdown
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='openpyxl.worksheet.header_footer')

# %%
# US manufacturing data
us_manufact_pmi = ManufacturingPmi.download().data
us_man_table = us_manufact_pmi.full_pmi_table

# US services data
us_serv_pmi = ServicesPmi.download().data
us_serv_table = us_serv_pmi.full_pmi_table

# US consumer data
us_consumer = ConsumerSurvey.download().data

# US housing data
us_housing = ConstructionSurvey.download().data

# Europe data
eu_survey = EuroSurvey.download().data

# Caixin PMI data
caixin_manufact_pmi = CaixinManufacturingPmi.download().data
caixin_serv_pmi = CaixinServicesPmi.download().data

# Market data from Trading Economics
market_data = MarketData.download().data
bonds_main = market_data.bonds.major10y
stocks_main = market_data.stocks.major
crypto_main = market_data.crypto.crypto
currencies_main = market_data.currencies.major
commodities = market_data.commodities.all

# Finviz data on inndustry and stock levels
industries = FinvizIndustries.download().data
stocks = FinvizSreener.download(num_rows=1000, view_col_nums='all').data

# %%
# Display downloaded data
show_list = {
    'US Manufacturing PMI':us_man_table, 'US Services PMI':us_serv_table, 'US Consumer Survey':us_consumer, 'US Construction Survey':us_housing, 
    'Europe Survey':eu_survey,  'Caixin Manufacturing PMI':caixin_manufact_pmi, 'Caixin Services PMI':caixin_serv_pmi,
    '10 Y Bonds': bonds_main, 'Major Stock Indices':stocks_main, 'Main Crypto Assets':crypto_main, 'Major Currencies':currencies_main, 
    'Commodities':commodities, 'Finviz Industries':industries, 'Finviz Stocks':stocks
    }

for heading, table in show_list.items():
    print('\n')
    display(Markdown(f'#### {heading}'))
    display(table)
# Out:
# #### US Manufacturing PMI
#                        Series Index Jun Series Index May  \
# Index
# Manufacturing PMI®                 49.0             48.5
# New Orders                         46.4             47.6
# Production                         50.3             45.4
# Employment                         45.0             46.8
# Supplier Deliveries                54.2             56.1
# Inventories                        49.2             46.7
# Customers’ Inventories             46.7             44.5
# Prices                             69.7             69.4
# Backlog of Orders                  44.3             47.1
# New Export Orders                  46.3             40.1
# Imports                            47.4             39.9
# OVERALL ECONOMY
# Manufacturing Sector
#
#                        Percentage Point Change    Direction    Rate of Change  \
# Index
# Manufacturing PMI®                         0.5  Contracting            Slower
# New Orders                                -1.2  Contracting            Faster
# Production                                 4.9      Growing  From Contracting
# Employment                                -1.8  Contracting            Faster
# Supplier Deliveries                       -1.9      Slowing            Slower
# Inventories                                2.5  Contracting            Slower
# Customers’ Inventories                     2.2      Too Low            Slower
# Prices                                     0.3   Increasing            Faster
# Backlog of Orders                         -2.8  Contracting            Faster
# New Export Orders                          6.2  Contracting            Slower
# Imports                                    7.5  Contracting            Slower
# OVERALL ECONOMY                                     Growing            Faster
# Manufacturing Sector                            Contracting            Slower
#
#                        Trend (Months)
# Index
# Manufacturing PMI®                4.0
# New Orders                        5.0
# Production                        1.0
# Employment                        5.0
# Supplier Deliveries               7.0
# Inventories                       2.0
# Customers’ Inventories            9.0
# Prices                            9.0
# Backlog of Orders                33.0
# New Export Orders                 4.0
# Imports                           3.0
# OVERALL ECONOMY                  62.0
# Manufacturing Sector              4.0
# #### US Services PMI
#                                  Services PMI®                   \
#                               Series Index Jun Series Index May
# Index
# Services PMI®                             50.8             49.9
# Business Activity/ Production             54.2             50.0
# New Orders                                51.3             46.4
# Employment                                47.2             50.7
# Supplier Deliveries                       50.3             52.5
# Inventories                               52.7             49.7
# Prices                                    67.5             68.7
# Backlog of Orders                         42.4             43.4
# New Export Orders                         51.1             48.5
# Imports                                   51.7             48.2
# Inventory Sentiment                       57.1             62.9
# Customers' Inventories                     N/A              N/A
# Overall Economy
# Services Sector
#
#                                                                  \
#                               Percent Point Change    Direction
# Index
# Services PMI®                                  0.9      Growing
# Business Activity/ Production                  4.2      Growing
# New Orders                                     4.9      Growing
# Employment                                    -3.5  Contracting
# Supplier Deliveries                           -2.2      Slowing
# Inventories                                    3.0      Growing
# Prices                                        -1.2   Increasing
# Backlog of Orders                             -1.0  Contracting
# New Export Orders                              2.6      Growing
# Imports                                        3.5      Growing
# Inventory Sentiment                           -5.8     Too High
# Customers' Inventories                         N/A          N/A
# Overall Economy                                         Growing
# Services Sector                                         Growing
#
#                                                                 \
#                                  Rate of Change Trend (Months)
# Index
# Services PMI®                  From Contracting            1.0
# Business Activity/ Production    From Unchanged            1.0
# New Orders                     From Contracting            1.0
# Employment                         From Growing            1.0
# Supplier Deliveries                      Slower            7.0
# Inventories                    From Contracting            1.0
# Prices                                   Slower           97.0
# Backlog of Orders                        Faster            4.0
# New Export Orders              From Contracting            1.0
# Imports                        From Contracting            1.0
# Inventory Sentiment                      Slower           26.0
# Customers' Inventories                      N/A            N/A
# Overall Economy                          Faster           61.0
# Services Sector                From Contracting            1.0
#
#                               Manufacturing PMI®                   \
#                                 Series Index Jun Series Index May
# Index
# Services PMI®                               49.0             48.5
# Business Activity/ Production               50.3             45.4
# New Orders                                  46.4             47.6
# Employment                                  45.0             46.8
# Supplier Deliveries                         54.2             56.1
# Inventories                                 49.2             46.7
# Prices                                      69.7             69.4
# Backlog of Orders                           44.3             47.1
# New Export Orders                           46.3             40.1
# Imports                                     47.4             39.9
# Inventory Sentiment                          N/A              N/A
# Customers' Inventories                      46.7             44.5
# Overall Economy
# Services Sector
#
#
#                               Percent Point Change
# Index
# Services PMI®                                  0.5
# Business Activity/ Production                  4.9
# New Orders                                    -1.2
# Employment                                    -1.8
# Supplier Deliveries                           -1.9
# Inventories                                    2.5
# Prices                                         0.3
# Backlog of Orders                             -2.8
# New Export Orders                              6.2
# Imports                                        7.5
# Inventory Sentiment                            N/A
# Customers' Inventories                         2.2
# Overall Economy
# Services Sector
# #### US Consumer Survey
#     Year  Month  Index  Current Index  Expected Index
# 0   2024      6   68.2           65.9            69.6
# 1   2024      7   66.4           62.7            68.8
# 2   2024      8   67.9           61.3            72.1
# 3   2024      9   70.1           63.3            74.4
# 4   2024     10   70.5           64.9            74.1
# 5   2024     11   71.8           63.9            76.9
# 6   2024     12   74.0           75.1            73.3
# 7   2025      1   71.7           75.1            69.5
# 8   2025      2   64.7           65.7            64.0
# 9   2025      3   57.0           63.8            52.6
# 10  2025      4   52.2           59.8            47.3
# 11  2025      5   52.2           58.9            47.9
# 12  2025      6   60.7           64.8            58.1
# #### US Construction Survey
#      Year  Month  Permits  Authorized  Starts  Under Construction  Completions
# 0    1959      1     <NA>        <NA>  1657.0                <NA>         <NA>
# 1    1959      2     <NA>        <NA>  1667.0                <NA>         <NA>
# 2    1959      3     <NA>        <NA>  1620.0                <NA>         <NA>
# 3    1959      4     <NA>        <NA>  1590.0                <NA>         <NA>
# 4    1959      5     <NA>        <NA>  1498.0                <NA>         <NA>
# ..    ...    ...      ...         ...     ...                 ...          ...
# 792  2025      1   1460.0       283.0  1358.0              1402.0       1651.0
# 793  2025      2   1454.0       277.0  1490.0              1408.0       1565.0
# 794  2025      3   1481.0       268.0  1355.0              1401.0       1566.0
# 795  2025      4   1422.0       276.0  1392.0              1394.0       1448.0
# 796  2025      5   1394.0       282.0  1256.0              1375.0       1526.0
#
# [797 rows x 7 columns]
# #### Europe Survey
#      Year  Month  EU.INDU EU.SERV  EU.CONS EU.RETA  EU.BUIL  EU.ESI  EU.EEI  \
# 0    1985      1     -5.8    <NA>    -10.2    <NA>    -48.9    95.0    81.5
# 1    1985      2     -7.4    <NA>    -10.6    <NA>    -48.1    93.7    79.3
# 2    1985      3     -8.4    <NA>    -11.5    <NA>    -45.6    91.9    80.7
# 3    1985      4     -7.9    <NA>    -10.8    <NA>    -43.5    92.7    81.5
# 4    1985      5     -7.1    <NA>    -11.2    <NA>    -43.2    93.7    81.9
# ..    ...    ...      ...     ...      ...     ...      ...     ...     ...
# 481  2025      2    -10.2     5.9    -12.9    -3.5     -5.9    96.9    98.4
# 482  2025      3    -10.0     3.9    -13.9    -5.4     -5.8    95.9    97.7
# 483  2025      4    -10.5     2.9    -15.9    -7.1     -5.7    94.5    96.9
# 484  2025      5    -10.5     2.8    -14.5    -5.8     -5.3    95.0    97.5
# 485  2025      6    -11.6     3.0    -14.8    -6.3     -4.6    94.0    97.5
#
#      EA.INDU  ... RS.BUIL  RS.ESI  RS.EEI  TR.INDU  TR.SERV  TR.CONS  TR.RETA  \
# 0       -5.9  ...    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>     <NA>
# 1       -8.0  ...    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>     <NA>
# 2       -9.5  ...    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>     <NA>
# 3       -8.8  ...    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>     <NA>
# 4       -7.6  ...    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>     <NA>
# ..       ...  ...     ...     ...     ...      ...      ...      ...      ...
# 481    -11.1  ...    -4.9    95.9   101.3     -1.8     21.1    -18.4     13.5
# 482    -10.7  ...    -2.2    94.1   100.3     -0.2     20.2    -14.6     11.8
# 483    -11.1  ...    -7.9    92.5    98.4     -1.0     17.2    -16.5     10.4
# 484    -10.4  ...    -5.4    90.4    97.8     -2.5     18.4    -15.5     11.9
# 485    -12.0  ...    -6.2    87.7    92.6     -2.2     19.3    -15.2      9.6
#
#     TR.BUIL  TR.ESI  TR.EEI
# 0      <NA>    <NA>    <NA>
# 1      <NA>    <NA>    <NA>
# 2      <NA>    <NA>    <NA>
# 3      <NA>    <NA>    <NA>
# 4      <NA>    <NA>    <NA>
# ..      ...     ...     ...
# 481   -10.6    97.1    99.8
# 482   -11.1    99.1    97.6
# 483   -14.6    95.9    94.7
# 484   -11.8    96.3    93.5
# 485   -13.3    96.6    92.4
#
# [486 rows x 247 columns]
# #### Caixin Manufacturing PMI
#    Year  Month  Manufacturing PMI
# 0  2025      6               50.4
# #### Caixin Services PMI
#    Year  Month  Services PMI
# 0  2025      6          50.6
# #### 10 Y Bonds
#           Major10Y   Yield  Weekly %  Monthly %  YTD %  YoY %    Date
# 0    United States    4.39      0.01       0.02  -0.19    0.2  Jul/11
# 1   United Kingdom    4.61      0.05       0.13   0.04    0.5  Jul/11
# 2            Japan   1.506      0.07       0.05   0.41   0.46  Jul/11
# 3        Australia   4.339      0.15        0.1  -0.03    0.0  Jul/11
# 4          Germany   2.666       0.1       0.19    0.3   0.17  Jul/11
# 5           Brazil  13.935      0.43      -0.06  -1.21   2.25  Jul/10
# 6           Russia   14.69      0.03      -0.35  -0.53  -0.75  Jul/10
# 7            India   6.305     -0.04      -0.02  -0.47  -0.66  Jul/11
# 8           Canada   3.449       0.1       0.12   0.21   0.04  Jul/11
# 9            Italy   3.587      0.12       0.18   0.07  -0.21  Jul/11
# 10          France    3.39      0.11       0.21    0.2   0.24  Jul/11
# 11    South Africa     9.9      0.18      -0.19   0.87   0.43  Jul/11
# 12     Switzerland   0.438      0.04        0.2   0.19   -0.2  Jul/11
# 13          Mexico    9.25      0.15      -0.01  -1.17  -0.52  Jul/10
# 14     Netherlands   2.888      0.11       0.19   0.29   0.11  Jul/11
# 15     New Zealand   4.536     -0.01      -0.06   0.11   0.04  Jul/11
# 16        Portugal   3.143       0.1       0.18    0.3   0.06  Jul/11
# 17     South Korea   3.146     -0.01      -0.01  -0.05  -0.41  Jul/10
# 18           Spain   3.312      0.09       0.23   0.25   0.05  Jul/11
# 19          Greece   3.401      0.12       0.17    0.2  -0.09  Jul/11
# 20          Turkey   31.65      0.88      -1.14   2.33   3.54  Jul/11
# #### Major Stock Indices
#        Major     Price  Day %  Weekly %  Monthly %  YTD %  YoY %    Date
# 0      US500   6249.12   -0.5      0.31       3.37   6.25  11.29  Jul/11
# 1       US30   44400.0  -0.56     -0.01       3.33   4.36   11.0  Jul/11
# 2      US100   22742.0  -0.38      0.25       3.78   8.23  11.85  Jul/11
# 3      JP225   39369.0   -0.7     -1.11       3.13  -1.32  -4.42  Jul/11
# 4      GB100    8933.0  -0.47      1.25       0.54    9.3   8.24  Jul/11
# 5       DE40   24257.0  -0.82      1.97       2.04  21.84  29.38  Jul/11
# 6       FR40    7826.0  -0.96      1.69       0.79   6.04   1.32  Jul/11
# 7       IT40   39914.0  -1.52      0.74      -0.09  16.75  15.42  Jul/11
# 8       ES35   14011.0  -0.92      0.27      -0.55  20.84  24.54  Jul/11
# 9     ASX200    8535.0  -0.63     -0.79      -0.35   4.61   7.23  Jul/11
# 10  SHANGHAI    3510.0   0.01      1.09       3.16   4.73  18.14  Jul/11
# 11    SENSEX   82500.0  -0.83     -1.12       0.99   5.58   2.46  Jul/11
# 12       TSX   27082.0   0.41      0.18        2.1   9.52  20.13  Jul/10
# 13      MOEX    2674.0  -2.13     -4.54      -2.76  -7.24 -10.12  Jul/11
# 14  IBOVESPA  136743.0  -0.54     -2.97      -0.28  13.68   6.59  Jul/10
# 15       IPC   56740.0   0.09     -1.99      -1.78  14.51   4.26  Jul/10
# 16      NL25     922.0  -0.57       1.5      -0.91   4.94  -2.42  Jul/11
# 17      CH20   11988.0  -1.19      0.13      -2.73   3.33  -3.05  Jul/11
# 18     SAALL   97043.0  -0.33     -0.14       0.01   15.4   18.8  Jul/11
# 19       STI    4088.0    0.3      1.85       4.22   7.93  16.87  Jul/11
# 20      HK50   24092.0   0.26      0.74       0.24   20.1   31.7  Jul/11
# 21    NZX 50   12687.0  -0.58     -0.63        0.3  -3.23   4.55  Jul/11
# 22      EU50    5387.0  -0.98      1.86       0.49  10.04   6.83  Jul/11
# #### Main Crypto Assets
#           Crypto     Price  Day %  Weekly %  Monthly %  YTD %   YoY %  \
# 0        Bitcoin  117803.0   1.56      9.04      11.21  26.25  103.66
# 1          Ether    2983.4   0.96     18.88      12.45 -10.43   -4.61
# 2        Binance     688.4   0.08      5.34       4.82  -1.36   29.65
# 3        Cardano   0.73553    8.5     28.45      10.93 -12.66   78.24
# 4         Solana  164.0224  -0.13     11.06       7.24 -13.21    18.0
# 5         Ripple   2.66782   4.65     20.13      21.55  28.62  463.43
# 6       Polkadot      3.96   2.07     17.96       0.78  -40.1  -34.93
# 7      Avalanche     21.04   1.69     18.27       3.34 -40.78   -18.8
# 8        Polygon      0.22   0.83     26.31       6.69 -50.03  -55.57
# 9         Cosmos      4.66   0.83     16.43       9.96 -24.54  -24.13
# 10           Dai   0.99984  -0.03       0.0      -0.04  -0.03   -0.01
# 11      Litecoin     95.45   0.56      9.93      10.53  -7.07   37.66
# 12       Uniswap      8.93   5.34     28.87      18.84 -32.41   10.18
# 13      Algorand      0.23   7.27     29.83      23.93 -33.75   64.45
# 14  Bitcoin Cash    522.13   0.67       7.9      22.52  20.33   41.74
# 15       Stellar    0.3281   8.39     38.01      22.52  -1.01  260.39
# 16        Monero   324.808  -0.43      3.63       1.89  68.54  103.74
# 17     Chainlink   15.5184   1.72      18.0       10.7  -22.1   22.14
# 18        Tether       1.0   0.01       0.0      -0.01   0.22   -0.01
# 19      USD Coin       1.0   0.02       0.0       0.01    0.0    0.01
#
#     Market Cap (m USD)    Date
# 0            2352242.0  Jul/11
# 1             456839.0  Jul/11
# 2              95968.0  Jul/11
# 3              26041.0  Jul/11
# 4              88084.0  Jul/11
# 5             156299.0  Jul/11
# 6               6320.0  Jul/11
# 7               8885.0  Jul/11
# 8                446.0  Jul/11
# 9               1824.0  Jul/11
# 10              5365.0  Jul/11
# 11              7284.0  Jul/11
# 12              5669.0  Jul/11
# 13              1937.0  Jul/11
# 14             10414.0  Jul/11
# 15              9991.0  Jul/11
# 16              6015.0  Jul/11
# 17             10500.0  Jul/11
# 18            159106.0  Jul/11
# 19             62849.0  Jul/11
# #### Major Currencies
#      Major     Price  Day %  Weekly %  Monthly %  YTD %  YoY %    Date
# 0   EURUSD   1.16892   -0.1     -0.69       0.91  12.85   7.18  Jul/11
# 1   GBPUSD   1.35079  -0.53     -1.03      -0.77    7.9    4.0  Jul/11
# 2   AUDUSD   0.65812  -0.18      0.54       0.74   6.33  -2.99  Jul/11
# 3   NZDUSD   0.60143  -0.43     -0.65      -0.83   7.53  -1.69  Jul/11
# 4   USDJPY   146.955   0.46      1.76       2.42  -6.61  -6.91  Jul/11
# 5   USDCNY   7.16715  -0.17      0.06      -0.09  -2.32  -1.42  Jul/11
# 6   USDCHF   0.79661  -0.01      0.23      -1.68 -12.21 -10.92  Jul/11
# 7   USDCAD   1.36704   0.11      0.59       0.49  -4.92   0.26  Jul/11
# 8   USDMXN   18.6992   0.53       0.4      -0.99 -10.32   6.15  Jul/11
# 9   USDINR    85.788   0.08      0.08       0.24   0.25   2.72  Jul/11
# 10  USDBRL     5.577   0.82      2.86       0.73  -9.82   2.72  Jul/11
# 11  USDRUB     77.96   0.53      -1.0      -2.55 -31.31 -11.28  Jul/11
# 12  USDKRW   1375.15   0.25      0.93       1.48  -6.97    0.0  Jul/11
# 13     DXY    97.792   0.14      0.85      -0.13  -9.86  -6.05  Jul/11
# 14  USDTRY   40.1749   0.03      0.83       2.16   13.7  21.57  Jul/11
# 15  USDSEK   9.53534    0.4     -0.14       0.94 -13.81  -9.01  Jul/11
# 16  USDPLN   3.64127   0.29       1.2      -1.15 -11.85   -6.6  Jul/11
# 17  USDNOK  10.11824   0.43      0.48       1.86 -11.12  -2.57  Jul/11
# 18  USDZAR   17.9085   0.97      1.93        0.6   -5.0  -0.25  Jul/11
# 19  USDDKK   6.38326   0.12       0.8      -0.87 -11.33  -6.68  Jul/11
# 20  USDSGD   1.27981   0.04      0.45        0.1  -6.29  -4.55  Jul/11
# 21  USDILS   3.33034    0.8     -0.13      -6.47  -8.44   -7.4  Jul/11
# 22  USDHKD   7.84994   0.01      0.03       0.01   1.07   0.54  Jul/11
# 23  USDCLP    953.76   0.36      2.56       2.54  -4.09   5.33  Jul/11
# 24  USDPKR   284.309  -0.07      0.18       0.69   2.13   2.28  Jul/11
# 25  USDCZK    21.103   0.27      0.97      -1.36 -13.25   -9.1  Jul/11
# 26  USDHUF   342.131   0.46      1.14      -1.28 -13.86  -4.75  Jul/11
# #### Commodities
#                Item     Category       Unit   Price  Day %  Weekly %  \
# 0        Crude Oil        Energy    USD/Bbl  67.265   1.04      1.22
# 1            Brent        Energy    USD/Bbl  69.294   0.95      1.48
# 2      Natural gas        Energy  USD/MMBtu  3.3672   0.91     -0.56
# 3         Gasoline        Energy    USD/Gal  2.1637   0.38      2.22
# 4      Heating Oil        Energy    USD/Gal  2.4129   1.23      0.17
# ..              ...          ...        ...     ...    ...       ...
# 88  United Kingdom   Electricity    GBP/MWh    75.2   1.62      3.01
# 89         Germany   Electricity    EUR/MWh   86.77  -0.75       3.3
# 90          France   Electricity    EUR/MWh   64.99   -0.4      2.43
# 91           Italy   Electricity    EUR/MWh  116.07   8.86     -8.22
# 92           Spain   Electricity    EUR/MWh   98.25  -8.15     -1.39
#
#     Monthly %  YTD %  YoY %    Date
# 0       -1.14  -6.21 -18.18  Jul/11
# 1       -0.09  -7.16 -18.51  Jul/11
# 2       -3.57  -7.32  44.58  Jul/11
# 3       -0.24   7.52 -13.81  Jul/11
# 4         8.7   4.13  -3.72  Jul/11
# ..        ...    ...    ...     ...
# 88      -2.53  -26.6  18.05  Jul/10
# 89      30.01 -25.02  30.27  Jul/10
# 90      -2.71  -6.96 -12.18  Jul/11
# 91      -0.29 -15.74    2.8  Jul/11
# 92       57.4 -27.68  67.15  Jul/11
#
# [93 rows x 10 columns]
# #### Finviz Industries
#                            Industry                  Sector  \
# 0              Advertising Agencies  Communication Services
# 1               Aerospace & Defense             Industrials
# 2               Agricultural Inputs         Basic Materials
# 3                          Airlines             Industrials
# 4           Airports & Air Services             Industrials
# ..                              ...                     ...
# 139  Utilities - Regulated Electric               Utilities
# 140       Utilities - Regulated Gas               Utilities
# 141     Utilities - Regulated Water               Utilities
# 142           Utilities - Renewable               Utilities
# 143                Waste Management             Industrials
#
#      Market Cap (m USD)    P/E  Fwd P/E   PEG   P/S   P/B    P/C  P/FCF  ...  \
# 0              199220.0  39.57     21.2  1.31  2.86  8.38  14.22  23.13  ...
# 1             1478950.0  43.16    29.64  2.95  3.01  7.15  23.23  46.81  ...
# 2              128170.0  31.45    16.76  2.98  1.65  1.67  21.28  20.19  ...
# 3              162040.0   13.1     9.48  0.72  0.59  2.69   3.03  12.35  ...
# 4               38210.0  26.32    19.15  2.06  5.04  5.41  10.47  29.83  ...
# ..                  ...    ...      ...   ...   ...   ...    ...    ...  ...
# 139           1123960.0  19.41    15.32  2.28  2.41  1.91  29.47  136.4  ...
# 140             87770.0   20.5    15.84  2.14   2.1  1.85  37.56  69.34  ...
# 141             64040.0  15.82    17.91  1.82  3.71  2.17  32.08  47.97  ...
# 142            154080.0  31.61    26.14  2.35  2.96  3.33   9.43  41.44  ...
# 143            251930.0  43.67    30.65  3.87  3.86  6.47  131.7  41.74  ...
#
#      Perf Quart (%)  Perf Half (%)  Perf Year (%)  Perf YTD (%)  Recom  \
# 0             39.71         -16.02          47.72        -10.74   1.71
# 1             33.71          28.01           37.6          27.1   1.84
# 2             34.91          23.39          31.38         27.54   2.11
# 3             51.44           2.46          13.12          2.82   1.72
# 4             49.63           22.8          40.43         32.43   2.52
# ..              ...            ...            ...           ...    ...
# 139            7.15           8.46          16.86          7.23   2.23
# 140            7.41          10.85          27.95          8.65   2.04
# 141            4.39           16.2          10.91         14.07   2.17
# 142           51.75          16.47          29.16         31.27    1.7
# 143            5.39          11.64          10.87          11.6   1.88
#
#      Avg Volume (m USD)  Rel Volume  Change (%)  Volume (m USD)  Stocks
# 0                 48.02         0.9        -0.6           43.43      42
# 1                 161.9        1.01       -0.22          162.96      75
# 2                 18.72        0.95       -2.15           17.73      16
# 3                135.24        2.27        8.23           306.7      18
# 4                 26.02        1.37        3.86           35.61       9
# ..                  ...         ...         ...             ...     ...
# 139              134.05        0.78        1.02          104.86      40
# 140               12.24        0.86        0.67           10.54      15
# 141                6.52        1.15       -0.22            7.52      14
# 142               19.43        6.77       -1.14           131.5      22
# 143                8.67        0.97        -0.1            8.45      19
#
# [144 rows x 27 columns]
# #### Finviz Stocks
#     Ticker                      Company    Index              Sector  \
# 0        A     Agilent Technologies Inc  S&P 500          Healthcare
# 1       AA                   Alcoa Corp     <NA>     Basic Materials
# 2     AACB    Artius II Acquisition Inc     <NA>           Financial
# 3     AACG    ATA Creativity Global ADR     <NA>  Consumer Defensive
# 4     AACI  Armada Acquisition Corp. II     <NA>           Financial
# ..     ...                          ...      ...                 ...
# 995    CGC    Canopy Growth Corporation     <NA>          Healthcare
# 996   CGCT    Cartesian Growth Corp III     <NA>           Financial
# 997  CGCTU    Cartesian Growth Corp III     <NA>           Financial
# 998   CGEM    Cullinan Therapeutics Inc      RUT          Healthcare
# 999   CGEN                 Compugen Ltd     <NA>          Healthcare
#
#                                      Industry Country Exchange  \
# 0                      Diagnostics & Research     USA     NYSE
# 1                                    Aluminum     USA     NYSE
# 2                             Shell Companies     USA     NASD
# 3               Education & Training Services   China     NASD
# 4                             Shell Companies     USA     NASD
# ..                                        ...     ...      ...
# 995  Drug Manufacturers - Specialty & Generic  Canada     NASD
# 996                           Shell Companies     USA     NASD
# 997                           Shell Companies     USA     NASD
# 998                             Biotechnology     USA     NASD
# 999                             Biotechnology  Israel     NASD
#
#      Market Cap (m USD)    P/E  Fwd P/E  ...  Avg Volume (m USD)  Rel Volume  \
# 0               35270.0  30.63    20.51  ...                 2.0        1.11
# 1                8170.0   9.34    11.65  ...                6.38        0.76
# 2                298.41   <NA>     <NA>  ...             0.14092        0.01
# 3                 27.29   <NA>     <NA>  ...             0.01618        1.04
# 4                275.44   <NA>     <NA>  ...             0.16882        0.59
# ..                  ...    ...      ...  ...                 ...         ...
# 995              215.88   <NA>     <NA>  ...                8.82        2.88
# 996              345.69   <NA>     <NA>  ...             0.20731        0.03
# 997              350.52   <NA>     <NA>  ...              0.4321        0.04
# 998              462.68   <NA>     <NA>  ...             0.41114        0.72
# 999              158.04   <NA>     <NA>  ...             0.21518        0.33
#
#        Volume  Target Price  Prev Close    Open    High     Low   Price  \
# 0     2269535        137.86       121.3  121.63  126.43  120.94  124.17
# 1     4958134         33.33       30.58   31.32   31.97   30.95   31.57
# 2        1193          <NA>       10.12   10.15   10.12   10.12   10.15
# 3       16596           6.5        0.85    0.83     0.9    0.82    0.85
# 4      103262          <NA>       10.04   10.05   10.06   10.03   10.03
# ..        ...           ...         ...     ...     ...     ...     ...
# 995  24458024          2.24        1.26    1.26    1.33    1.16    1.19
# 996      6911          <NA>       10.02   10.02   10.02   10.02   10.02
# 997     16187          <NA>       10.16   10.16   10.16   10.16   10.16
# 998    297306          27.0         7.8    7.78    7.94    7.62    7.84
# 999     74092           5.5        1.67     1.7    1.74    1.69    1.69
#
#      Change (%)
# 0          2.37
# 1          3.24
# 2           0.3
# 3          0.45
# 4          -0.1
# ..          ...
# 995       -5.56
# 996         0.0
# 997         0.0
# 998        0.51
# 999         1.2
#
# [1000 rows x 96 columns]
