# %%
from Scrapers import *
from IPython.display import display, Markdown
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='openpyxl.worksheet.header_footer')

# %%
# US manufacturing data
us_manufact_pmi = ManufacturingPmi.download().data
us_man_table = us_manufact_pmi.full_pmi_table

# US services data
us_serv_pmi = ServicesPmi.download().data
us_serv_table = us_serv_pmi.full_pmi_table

# US consumer data
us_consumer = ConsumerSurvey.download().data

# US housing data
us_housing = ConstructionSurvey.download().data

# Europe data
eu_survey = EuroSurvey.download().data

# Caixin PMI data
caixin_manufact_pmi = CaixinManufacturingPmi.download().data
caixin_serv_pmi = CaixinServicesPmi.download().data

# Market data from Trading Economics
market_data = MarketData.download().data
bonds_main = market_data.bonds.major10y
stocks_main = market_data.stocks.major
crypto_main = market_data.crypto.crypto
currencies_main = market_data.currencies.major
commodities = market_data.commodities.all

# Finviz data on inndustry and stock levels
industries = FinvizIndustries.download().data
stocks = FinvizSreener.download(num_rows=1000, view_col_nums='all').data

# %%
# Display downloaded data
show_list = {
    'US Manufacturing PMI':us_man_table, 'US Services PMI':us_serv_table, 'US Consumer Survey':us_consumer, 'US Construction Survey':us_housing, 
    'Europe Survey':eu_survey,  'Caixin Manufacturing PMI':caixin_manufact_pmi, 'Caixin Services PMI':caixin_serv_pmi,
    '10 Y Bonds': bonds_main, 'Major Stock Indices':stocks_main, 'Main Crypto Assets':crypto_main, 'Major Currencies':currencies_main, 
    'Commodities':commodities, 'Finviz Industries':industries, 'Finviz Stocks':stocks
    }

for heading, table in show_list.items():
    print('\n')
    display(Markdown(f'#### {heading}'))
    display(table)
# Out:
# #### US Manufacturing PMI
#                        Series Index Jun Series Index May  \
# Index
# Manufacturing PMI®                 49.0             48.5
# New Orders                         46.4             47.6
# Production                         50.3             45.4
# Employment                         45.0             46.8
# Supplier Deliveries                54.2             56.1
# Inventories                        49.2             46.7
# Customers’ Inventories             46.7             44.5
# Prices                             69.7             69.4
# Backlog of Orders                  44.3             47.1
# New Export Orders                  46.3             40.1
# Imports                            47.4             39.9
# OVERALL ECONOMY
# Manufacturing Sector
#
#                        Percentage Point Change    Direction    Rate of Change  \
# Index
# Manufacturing PMI®                         0.5  Contracting            Slower
# New Orders                                -1.2  Contracting            Faster
# Production                                 4.9      Growing  From Contracting
# Employment                                -1.8  Contracting            Faster
# Supplier Deliveries                       -1.9      Slowing            Slower
# Inventories                                2.5  Contracting            Slower
# Customers’ Inventories                     2.2      Too Low            Slower
# Prices                                     0.3   Increasing            Faster
# Backlog of Orders                         -2.8  Contracting            Faster
# New Export Orders                          6.2  Contracting            Slower
# Imports                                    7.5  Contracting            Slower
# OVERALL ECONOMY                                     Growing            Faster
# Manufacturing Sector                            Contracting            Slower
#
#                        Trend (Months)
# Index
# Manufacturing PMI®                4.0
# New Orders                        5.0
# Production                        1.0
# Employment                        5.0
# Supplier Deliveries               7.0
# Inventories                       2.0
# Customers’ Inventories            9.0
# Prices                            9.0
# Backlog of Orders                33.0
# New Export Orders                 4.0
# Imports                           3.0
# OVERALL ECONOMY                  62.0
# Manufacturing Sector              4.0
# #### US Services PMI
#                                  Services PMI®                   \
#                               Series Index Jun Series Index May
# Index
# Services PMI®                             50.8             49.9
# Business Activity/ Production             54.2             50.0
# New Orders                                51.3             46.4
# Employment                                47.2             50.7
# Supplier Deliveries                       50.3             52.5
# Inventories                               52.7             49.7
# Prices                                    67.5             68.7
# Backlog of Orders                         42.4             43.4
# New Export Orders                         51.1             48.5
# Imports                                   51.7             48.2
# Inventory Sentiment                       57.1             62.9
# Customers' Inventories                     N/A              N/A
# Overall Economy
# Services Sector
#
#                                                                  \
#                               Percent Point Change    Direction
# Index
# Services PMI®                                  0.9      Growing
# Business Activity/ Production                  4.2      Growing
# New Orders                                     4.9      Growing
# Employment                                    -3.5  Contracting
# Supplier Deliveries                           -2.2      Slowing
# Inventories                                    3.0      Growing
# Prices                                        -1.2   Increasing
# Backlog of Orders                             -1.0  Contracting
# New Export Orders                              2.6      Growing
# Imports                                        3.5      Growing
# Inventory Sentiment                           -5.8     Too High
# Customers' Inventories                         N/A          N/A
# Overall Economy                                         Growing
# Services Sector                                         Growing
#
#                                                                 \
#                                  Rate of Change Trend (Months)
# Index
# Services PMI®                  From Contracting            1.0
# Business Activity/ Production    From Unchanged            1.0
# New Orders                     From Contracting            1.0
# Employment                         From Growing            1.0
# Supplier Deliveries                      Slower            7.0
# Inventories                    From Contracting            1.0
# Prices                                   Slower           97.0
# Backlog of Orders                        Faster            4.0
# New Export Orders              From Contracting            1.0
# Imports                        From Contracting            1.0
# Inventory Sentiment                      Slower           26.0
# Customers' Inventories                      N/A            N/A
# Overall Economy                          Faster           61.0
# Services Sector                From Contracting            1.0
#
#                               Manufacturing PMI®                   \
#                                 Series Index Jun Series Index May
# Index
# Services PMI®                               49.0             48.5
# Business Activity/ Production               50.3             45.4
# New Orders                                  46.4             47.6
# Employment                                  45.0             46.8
# Supplier Deliveries                         54.2             56.1
# Inventories                                 49.2             46.7
# Prices                                      69.7             69.4
# Backlog of Orders                           44.3             47.1
# New Export Orders                           46.3             40.1
# Imports                                     47.4             39.9
# Inventory Sentiment                          N/A              N/A
# Customers' Inventories                      46.7             44.5
# Overall Economy
# Services Sector
#
#
#                               Percent Point Change
# Index
# Services PMI®                                  0.5
# Business Activity/ Production                  4.9
# New Orders                                    -1.2
# Employment                                    -1.8
# Supplier Deliveries                           -1.9
# Inventories                                    2.5
# Prices                                         0.3
# Backlog of Orders                             -2.8
# New Export Orders                              6.2
# Imports                                        7.5
# Inventory Sentiment                            N/A
# Customers' Inventories                         2.2
# Overall Economy
# Services Sector
# #### US Consumer Survey
#     Year  Month  Index  Current Index  Expected Index
# 0   2024      6   68.2           65.9            69.6
# 1   2024      7   66.4           62.7            68.8
# 2   2024      8   67.9           61.3            72.1
# 3   2024      9   70.1           63.3            74.4
# 4   2024     10   70.5           64.9            74.1
# 5   2024     11   71.8           63.9            76.9
# 6   2024     12   74.0           75.1            73.3
# 7   2025      1   71.7           75.1            69.5
# 8   2025      2   64.7           65.7            64.0
# 9   2025      3   57.0           63.8            52.6
# 10  2025      4   52.2           59.8            47.3
# 11  2025      5   52.2           58.9            47.9
# 12  2025      6   60.7           64.8            58.1
# #### US Construction Survey
#      Year  Month  Permits  Authorized  Starts  Under Construction  Completions
# 0    1959      1     <NA>        <NA>  1657.0                <NA>         <NA>
# 1    1959      2     <NA>        <NA>  1667.0                <NA>         <NA>
# 2    1959      3     <NA>        <NA>  1620.0                <NA>         <NA>
# 3    1959      4     <NA>        <NA>  1590.0                <NA>         <NA>
# 4    1959      5     <NA>        <NA>  1498.0                <NA>         <NA>
# ..    ...    ...      ...         ...     ...                 ...          ...
# 792  2025      1   1460.0       283.0  1358.0              1402.0       1651.0
# 793  2025      2   1454.0       277.0  1490.0              1408.0       1565.0
# 794  2025      3   1481.0       268.0  1355.0              1401.0       1566.0
# 795  2025      4   1422.0       276.0  1392.0              1394.0       1448.0
# 796  2025      5   1394.0       282.0  1256.0              1375.0       1526.0
#
# [797 rows x 7 columns]
# #### Europe Survey
#      Year  Month  EU.INDU EU.SERV  EU.CONS EU.RETA  EU.BUIL  EU.ESI  EU.EEI  \
# 0    1985      1     -5.8    <NA>    -10.2    <NA>    -48.9    95.0    81.5
# 1    1985      2     -7.4    <NA>    -10.6    <NA>    -48.1    93.7    79.3
# 2    1985      3     -8.4    <NA>    -11.5    <NA>    -45.6    91.9    80.7
# 3    1985      4     -7.9    <NA>    -10.8    <NA>    -43.5    92.7    81.5
# 4    1985      5     -7.1    <NA>    -11.2    <NA>    -43.2    93.7    81.9
# ..    ...    ...      ...     ...      ...     ...      ...     ...     ...
# 481  2025      2    -10.2     5.9    -12.9    -3.5     -5.9    96.9    98.4
# 482  2025      3    -10.0     3.9    -13.9    -5.4     -5.8    95.9    97.7
# 483  2025      4    -10.5     2.9    -15.9    -7.1     -5.7    94.5    96.9
# 484  2025      5    -10.5     2.8    -14.5    -5.8     -5.3    95.0    97.5
# 485  2025      6    -11.6     3.0    -14.8    -6.3     -4.6    94.0    97.5
#
#      EA.INDU  ... RS.BUIL  RS.ESI  RS.EEI  TR.INDU  TR.SERV  TR.CONS  TR.RETA  \
# 0       -5.9  ...    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>     <NA>
# 1       -8.0  ...    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>     <NA>
# 2       -9.5  ...    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>     <NA>
# 3       -8.8  ...    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>     <NA>
# 4       -7.6  ...    <NA>    <NA>    <NA>     <NA>     <NA>     <NA>     <NA>
# ..       ...  ...     ...     ...     ...      ...      ...      ...      ...
# 481    -11.1  ...    -4.9    95.9   101.3     -1.8     21.1    -18.4     13.5
# 482    -10.7  ...    -2.2    94.1   100.3     -0.2     20.2    -14.6     11.8
# 483    -11.1  ...    -7.9    92.5    98.4     -1.0     17.2    -16.5     10.4
# 484    -10.4  ...    -5.4    90.4    97.8     -2.5     18.4    -15.5     11.9
# 485    -12.0  ...    -6.2    87.7    92.6     -2.2     19.3    -15.2      9.6
#
#     TR.BUIL  TR.ESI  TR.EEI
# 0      <NA>    <NA>    <NA>
# 1      <NA>    <NA>    <NA>
# 2      <NA>    <NA>    <NA>
# 3      <NA>    <NA>    <NA>
# 4      <NA>    <NA>    <NA>
# ..      ...     ...     ...
# 481   -10.6    97.1    99.8
# 482   -11.1    99.1    97.6
# 483   -14.6    95.9    94.7
# 484   -11.8    96.3    93.5
# 485   -13.3    96.6    92.4
#
# [486 rows x 247 columns]
# #### Caixin Manufacturing PMI
#    Year  Month  Manufacturing PMI
# 0  2025      6               50.4
# #### Caixin Services PMI
#    Year  Month  Services PMI
# 0  2025      6          50.6
# #### 10 Y Bonds
#           Major10Y   Yield  Weekly %  Monthly %  YTD %  YoY %    Date
# 0    United States   4.331     -0.02       -0.1  -0.25   0.11  Jul/10
# 1   United Kingdom   4.606     -0.01       0.06   0.04   0.47  Jul/09
# 2            Japan   1.499      0.06       0.04   0.41   0.42  Jul/10
# 3        Australia   4.282       0.1        0.0  -0.09  -0.09  Jul/10
# 4          Germany  2.6315      0.01        0.1   0.27    0.1  Jul/09
# 5           Brazil   13.72      0.22      -0.46  -1.43   1.79  Jul/08
# 6           Russia   14.78      0.15      -0.32  -0.44  -0.68  Jul/09
# 7            India    6.31     -0.04      -0.05  -0.48  -0.67  Jul/09
# 8           Canada   3.381      0.02       0.04   0.15   -0.1  Jul/09
# 9            Italy   3.548      0.02       0.11   0.03  -0.32  Jul/09
# 10          France   3.357      0.04       0.15   0.16   0.17  Jul/09
# 11    South Africa    9.84      0.02      -0.23   0.81   -0.1  Jul/09
# 12     Switzerland  0.4115       0.0       0.15   0.16   -0.2  Jul/09
# 13          Mexico   9.214      0.07       0.05   -1.2  -0.68  Jul/09
# 14     Netherlands    2.84      0.02        0.1   0.25   0.02  Jul/09
# 15     New Zealand   4.551       0.0      -0.09   0.13  -0.02  Jul/10
# 16        Portugal   3.118      0.03       0.12   0.28  -0.01  Jul/09
# 17     South Korea   2.821     -0.01      -0.01  -0.05  -0.41  Jul/10
# 18           Spain   3.275      0.01       0.17   0.21  -0.03  Jul/09
# 19          Greece    3.36       0.0       0.13   0.16  -0.19  Jul/09
# 20          Turkey   29.46      1.02      -1.27   2.27   3.37  Jul/09
# #### Major Stock Indices
#        Major     Price  Day %  Weekly %  Monthly %  YTD %  YoY %    Date
# 0      US500   6254.27  -0.14      -0.4       3.85   6.34  11.99  Jul/10
# 1       US30   44402.0  -0.13     -0.95       3.58   4.37  11.69  Jul/10
# 2      US100   22828.0  -0.16     -0.17       4.43   8.64  12.95  Jul/10
# 3      JP225   39581.0   -0.6     -0.52       3.02  -0.79  -6.26  Jul/10
# 4      GB100    8867.0   0.15      1.05       0.16   8.49   8.22  Jul/09
# 5       DE40   24580.0   0.12       2.7       2.63  23.46  32.61  Jul/10
# 6       FR40    7878.0   1.44      1.81       0.95   6.74   4.03  Jul/09
# 7       IT40   40821.0   1.59       2.6       1.53  19.41  18.99  Jul/09
# 8       ES35   14254.0   1.24      1.49       0.23  22.94  28.75  Jul/09
# 9     ASX200    8553.0   0.17      -0.5      -0.45   4.83   8.41  Jul/10
# 10  SHANGHAI    3492.0  -0.04      1.06       3.15   4.17  18.78  Jul/10
# 11    SENSEX   83536.0  -0.21      0.15       1.39   6.91   4.52  Jul/09
# 12       TSX   26972.0   0.26      0.38       2.07   9.08  20.68  Jul/09
# 13      MOEX    2696.0  -2.15     -4.22      -0.95  -6.47  -9.53  Jul/09
# 14  IBOVESPA  137481.0  -1.31     -1.13       0.77   14.3   8.07  Jul/09
# 15       IPC   56688.0  -0.87     -2.84      -2.43  14.41   4.44  Jul/09
# 16      NL25     919.0   0.22      0.91      -2.12   4.57  -2.22  Jul/09
# 17      CH20   12007.0    0.3      0.12      -2.79    3.5  -1.19  Jul/09
# 18     SAALL   97230.0  -0.03      0.64       0.59  15.62  20.86  Jul/09
# 19       STI    4069.0   0.27      1.22       3.82   7.42  17.09  Jul/10
# 20      HK50   23840.0  -0.22     -0.96      -2.16  18.84  33.69  Jul/10
# 21    NZX 50   12774.0  -0.19      0.55       1.33  -2.57   5.93  Jul/10
# 22      EU50    5455.0   0.21       2.1       1.15  11.42   9.63  Jul/10
# #### Main Crypto Assets
#           Crypto     Price  Day %  Weekly %  Monthly %  YTD %   YoY %  \
# 0        Bitcoin  111125.0  -0.17      1.35       2.25  19.09   93.83
# 1          Ether    2769.5  -0.07      6.89      -0.25 -16.85  -10.55
# 2        Binance     668.7   0.09      0.94        0.2  -4.18   27.84
# 3        Cardano   0.62121  -0.29      3.66     -11.05 -26.23   57.51
# 4         Solana  156.9412  -0.18      2.97      -2.51 -16.96   15.44
# 5         Ripple     2.414   0.35      6.94       6.31  16.39  437.49
# 6       Polkadot      3.62  -0.13      2.24     -13.76 -45.34  -38.73
# 7      Avalanche     19.49   -0.1      5.14      -9.77 -45.14  -22.75
# 8        Polygon      0.21  -1.14      9.41     -11.08 -54.27  -58.64
# 9         Cosmos       4.3  -0.24      2.82      -4.52 -30.28  -27.54
# 10           Dai   1.00069   0.04      0.06       0.08   0.06    0.08
# 11      Litecoin     90.62  -0.14      1.76      -1.03 -11.77   34.43
# 12       Uniswap      8.19  -1.38      9.72       0.39  -38.0     4.9
# 13      Algorand      0.19   7.43      5.12      -7.97 -43.47   39.41
# 14  Bitcoin Cash    512.13  -0.46      3.11      19.55  18.03   47.49
# 15       Stellar   0.28925   0.48     19.19       4.46 -12.73  226.32
# 16        Monero    327.73   0.52      2.53      -0.83  70.06   106.6
# 17     Chainlink   14.2383  -0.14      4.25      -4.53 -28.52   15.47
# 18        Tether       1.0    0.0       0.0       0.02   0.23    0.02
# 19      USD Coin       1.0    0.0       0.0       0.01    0.0     0.0
#
#     Market Cap (m USD)    Date
# 0            2214487.0  Jul/10
# 1             422969.0  Jul/10
# 2              94306.0  Jul/10
# 3              22099.0  Jul/10
# 4              84345.0  Jul/10
# 5             142606.0  Jul/10
# 6               5781.0  Jul/10
# 7               8268.0  Jul/10
# 8                408.0  Jul/10
# 9               1687.0  Jul/10
# 10              5367.0  Jul/10
# 11              6910.0  Jul/10
# 12              5240.0  Jul/10
# 13              1661.0  Jul/09
# 14             10254.0  Jul/10
# 15              9012.0  Jul/10
# 16              6021.0  Jul/10
# 17              9679.0  Jul/10
# 18            158714.0  Jul/10
# 19             61942.0  Jul/10
# #### Major Currencies
#      Major     Price  Day %  Weekly %  Monthly %  YTD %  YoY %    Date
# 0   EURUSD   1.17385   0.01     -0.26       2.18  13.32   7.95  Jul/10
# 1   GBPUSD   1.36044   0.05     -0.44       0.46   8.67   5.27  Jul/10
# 2   AUDUSD   0.65421    0.1     -0.52       0.64    5.7  -3.36  Jul/10
# 3   NZDUSD   0.60021   0.06     -1.26      -0.54   7.31  -1.52  Jul/10
# 4   USDJPY    145.89  -0.14      0.82       0.92  -7.28  -7.82  Jul/10
# 5   USDCNY   7.18027  -0.02      0.17      -0.26  -2.14  -1.13  Jul/10
# 6   USDCHF   0.79291   0.04     -0.17      -3.38 -12.62 -11.51  Jul/10
# 7   USDCAD   1.36805  -0.04      0.78       0.06  -4.85   0.41  Jul/10
# 8   USDMXN   18.6126    0.0     -0.19      -1.58 -10.73   4.82  Jul/10
# 9   USDINR     85.68  -0.06      0.31       0.27   0.12   2.58  Jul/10
# 10  USDBRL    5.5832   0.09      3.21       0.84  -9.72   2.63  Jul/10
# 11  USDRUB     78.16  -0.43     -0.97       -0.4 -31.13 -11.53  Jul/09
# 12  USDKRW   1374.15   0.01      0.78       0.29  -7.04   0.15  Jul/10
# 13     DXY     97.35   0.06      0.17       -1.3 -10.27  -6.72  Jul/10
# 14  USDTRY   40.0454    0.1      0.62       2.29  13.33  21.45  Jul/10
# 15  USDSEK   9.49685   0.02     -0.75      -0.64 -14.16  -9.51  Jul/10
# 16  USDPLN   3.61366   0.01      0.31       -2.4 -12.51  -7.75  Jul/10
# 17  USDNOK  10.07759    0.0      0.27       0.23 -11.48  -5.94  Jul/10
# 18  USDZAR    17.797   0.07      1.66       0.41  -5.59  -1.05  Jul/10
# 19  USDDKK   6.35534  -0.01      0.25      -2.13 -11.72  -7.36  Jul/10
# 20  USDSGD   1.27927  -0.01      0.41      -0.46  -6.33  -4.69  Jul/10
# 21  USDILS   3.29782  -0.11     -0.67      -6.69  -9.34  -9.17  Jul/10
# 22  USDHKD   7.84991    0.0      0.03       0.01   1.07   0.54  Jul/10
# 23  USDCLP    949.44   0.63       2.5        1.2  -4.52   4.13  Jul/09
# 24  USDPKR   283.386   -0.3      -0.2       0.44    1.8   1.64  Jul/10
# 25  USDCZK   20.9916   0.01      0.33      -2.69 -13.71  -10.0  Jul/10
# 26  USDHUF   340.324   0.02      0.49      -2.27 -14.32  -5.99  Jul/10
# #### Commodities
#                Item     Category       Unit   Price  Day %  Weekly %  \
# 0        Crude Oil        Energy    USD/Bbl  68.312   -0.1      2.22
# 1            Brent        Energy    USD/Bbl  70.105  -0.12      2.13
# 2      Natural gas        Energy  USD/MMBtu  3.2123  -0.05     -6.78
# 3         Gasoline        Energy    USD/Gal  2.1912   0.09      3.36
# 4      Heating Oil        Energy    USD/Gal  2.4149   0.18      2.05
# ..              ...          ...        ...     ...    ...       ...
# 88  United Kingdom   Electricity    GBP/MWh    74.0  -0.27      0.82
# 89         Germany   Electricity    EUR/MWh   88.67    0.0      3.68
# 90          France   Electricity    EUR/MWh    64.2   1.26      2.07
# 91           Italy   Electricity    EUR/MWh  106.62   5.75    -12.31
# 92           Spain   Electricity    EUR/MWh  106.97  19.25     17.12
#
#     Monthly %  YTD %  YoY %    Date
# 0        0.24  -4.75 -17.32  Jul/10
# 1        0.48  -6.08 -17.91  Jul/10
# 2        -8.4 -11.58  41.64  Jul/10
# 3        1.05   8.88 -13.28  Jul/10
# 4        9.34   4.22   -4.3  Jul/10
# ..        ...    ...    ...     ...
# 88      -0.94 -27.77  16.72  Jul/09
# 89      33.32 -23.38  32.32  Jul/09
# 90       3.05  -8.09 -14.17  Jul/09
# 91      -8.53  -22.6 -10.09  Jul/10
# 92      45.28 -21.26  25.07  Jul/10
#
# [93 rows x 10 columns]
# #### Finviz Industries
#                            Industry                  Sector  \
# 0              Advertising Agencies  Communication Services
# 1               Aerospace & Defense             Industrials
# 2               Agricultural Inputs         Basic Materials
# 3                          Airlines             Industrials
# 4           Airports & Air Services             Industrials
# ..                              ...                     ...
# 139  Utilities - Regulated Electric               Utilities
# 140       Utilities - Regulated Gas               Utilities
# 141     Utilities - Regulated Water               Utilities
# 142           Utilities - Renewable               Utilities
# 143                Waste Management             Industrials
#
#      Market Cap (m USD)    P/E  Fwd P/E   PEG   P/S   P/B     P/C   P/FCF  \
# 0              200480.0  39.85    21.18   1.3  2.88  8.44   14.31   23.28
# 1             1482650.0  43.28    29.76  2.95  3.02  7.17   23.29   46.93
# 2              130990.0  32.14    17.12  3.06  1.68  1.71   21.75   20.64
# 3              149720.0   12.1     8.73  0.65  0.55  2.49    2.81   11.41
# 4               36790.0  25.34    18.44  1.98  4.85   5.2   10.08   28.72
# ..                  ...    ...      ...   ...   ...   ...     ...     ...
# 139           1112630.0  19.21    15.16  2.25  2.39  1.89   29.18  135.02
# 140             87200.0  20.37    15.73  2.12  2.09  1.84   37.32   68.89
# 141             64200.0  15.86    17.95  1.81  3.72  2.17   32.12   48.05
# 142            155750.0  31.95    26.45  2.39  2.99  3.37    9.53   41.89
# 143            252190.0  43.72    30.71  3.89  3.86  6.48  131.83   41.78
#
#      ...  Perf Quart (%)  Perf Half (%)  Perf Year (%)  Perf YTD (%)  Recom  \
# 0    ...           39.98         -14.51           47.9         -10.2   1.71
# 1    ...           35.61          26.75           38.6         27.37   1.82
# 2    ...           35.81          28.78          32.96         30.35   2.11
# 3    ...           35.64          -3.39           4.93          -5.0   1.73
# 4    ...           40.26           20.6          33.29         27.51   2.52
# ..   ...             ...            ...            ...           ...    ...
# 139  ...            5.32           5.84          15.58          6.16   2.23
# 140  ...            6.74           8.03          26.69          7.93   2.04
# 141  ...            3.29          15.31          11.06         14.33   2.16
# 142  ...           54.98          21.97          32.42         32.76    1.7
# 143  ...            4.02          11.76          11.21         11.71   1.88
#
#      Avg Volume (m USD)  Rel Volume  Change (%)  Volume (m USD)  Stocks
# 0                 48.01        1.06        0.61           50.93      42
# 1                161.27        0.94        1.13          151.18      75
# 2                 18.79        0.98        0.55           18.38      16
# 3                132.95        1.08       -0.44          143.73      18
# 4                 25.69        0.91       -0.41           23.37       9
# ..                  ...         ...         ...             ...     ...
# 139              134.94        0.83        0.62          111.41      40
# 140                12.3        0.84        0.83            10.3      15
# 141                6.53        0.86        0.14             5.6      14
# 142               17.56        1.03        1.29           18.02      22
# 143                8.71        0.93        0.36             8.1      19
#
# [144 rows x 27 columns]
# #### Finviz Stocks
#     Ticker                      Company    Index              Sector  \
# 0        A     Agilent Technologies Inc  S&P 500          Healthcare
# 1       AA                   Alcoa Corp     <NA>     Basic Materials
# 2     AACB    Artius II Acquisition Inc     <NA>           Financial
# 3     AACG    ATA Creativity Global ADR     <NA>  Consumer Defensive
# 4     AACI  Armada Acquisition Corp. II     <NA>           Financial
# ..     ...                          ...      ...                 ...
# 995   CGCT    Cartesian Growth Corp III     <NA>           Financial
# 996  CGCTU    Cartesian Growth Corp III     <NA>           Financial
# 997   CGEM    Cullinan Therapeutics Inc      RUT          Healthcare
# 998   CGEN                 Compugen Ltd     <NA>          Healthcare
# 999   CGNT         Cognyte Software Ltd     <NA>          Technology
#
#                           Industry Country Exchange  Market Cap (m USD)  \
# 0           Diagnostics & Research     USA     NYSE             34460.0
# 1                         Aluminum     USA     NYSE              7920.0
# 2                  Shell Companies     USA     NASD              297.53
# 3    Education & Training Services   China     NASD               27.17
# 4                  Shell Companies     USA     NASD              275.71
# ..                             ...     ...      ...                 ...
# 995                Shell Companies     USA     NASD              345.69
# 996                Shell Companies     USA     NASD              350.52
# 997                  Biotechnology     USA     NASD              460.32
# 998                  Biotechnology  Israel     NASD              156.16
# 999      Software - Infrastructure  Israel     NASD              657.68
#
#        P/E  Fwd P/E  ...  Avg Volume (m USD)  Rel Volume   Volume  \
# 0    29.92    20.04  ...                2.09        0.87  1806701
# 1     9.05    11.28  ...                6.62         0.7  4610994
# 2     <NA>     <NA>  ...             0.14501         0.0      146
# 3     <NA>     <NA>  ...             0.01571        1.74    27380
# 4     <NA>     <NA>  ...             0.18189        0.57   103680
# ..     ...      ...  ...                 ...         ...      ...
# 995   <NA>     <NA>  ...             0.24771        0.01     3677
# 996   <NA>     <NA>  ...             0.45136         0.0      284
# 997   <NA>     <NA>  ...             0.41564        0.86   357478
# 998   <NA>     <NA>  ...             0.22566         0.5   113510
# 999   <NA>    33.85  ...             0.33659        0.57   191593
#
#      Target Price  Prev Close   Open    High    Low  Price  Change (%)
# 0          137.86      121.01  121.4  122.35  118.9  121.3        0.24
# 1           33.33       30.51  30.61   30.96  30.23  30.58        0.23
# 2            <NA>       10.11  10.11   10.12  10.12  10.12         0.1
# 3             6.5        0.83   0.82    0.85   0.82   0.85        2.58
# 4            <NA>       10.03  10.06   10.08  10.04  10.04        0.05
# ..            ...         ...    ...     ...    ...    ...         ...
# 995          <NA>       10.02  10.01   10.02  10.02  10.02        0.05
# 996          <NA>       10.14  10.16   10.16  10.16  10.16         0.2
# 997          27.0        7.35   7.43    7.81   7.38    7.8        6.12
# 998           5.5         1.7   1.72    1.73   1.66   1.67       -1.76
# 999          10.0        9.14   9.17     9.3   9.11   9.14         0.0
#
# [1000 rows x 96 columns]
